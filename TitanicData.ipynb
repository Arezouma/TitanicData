# %%
import os
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# 1. a- Load Titanic train and test set into respective DataFrames, train and test

# %%
# Load train dataset into train and display the five rows
cur_path = os.getcwd()
datapath = cur_path + '/Data/Titanic/'
train = pd.read_csv(datapath + 'train.csv', sep=',')


train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
# Load test dataset into test and display the five rows

test = pd.read_csv(datapath + 'test.csv', sep=',')
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %% [markdown]
# 1. b- Combine train dataset and test dataset into data, DataFrame using pandas concatenate

# %%
# Combine train and test sets into a single DataFrame, data and display the five rows
data = pd.concat([train,test])
data.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
# ...

# %% [markdown]
# 3.
#    1- Obtain information and representation of each variable
#    2- The meaning of values
#    3- Numerical summary

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 417
# Data columns (total 12 columns):
# Age            1046 non-null float64
# Cabin          295 non-null object
# Embarked       1307 non-null object
# Fare           1308 non-null float64
# Name           1309 non-null object
# Parch          1309 non-null int64
# PassengerId    1309 non-null int64
# Pclass         1309 non-null int64
# Sex            1309 non-null object
# SibSp          1309 non-null int64
# Survived       891 non-null float64
# Ticket         1309 non-null object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 132.9+ KB

# %%
# Description of the data
data.describe().T
# Out:
#               count        mean         std   min       25%       50%  \
# Age          1046.0   29.881138   14.413493  0.17   21.0000   28.0000
# Fare         1308.0   33.295479   51.758668  0.00    7.8958   14.4542
# Parch        1309.0    0.385027    0.865560  0.00    0.0000    0.0000
# PassengerId  1309.0  655.000000  378.020061  1.00  328.0000  655.0000
# Pclass       1309.0    2.294882    0.837836  1.00    2.0000    3.0000
# SibSp        1309.0    0.498854    1.041658  0.00    0.0000    0.0000
# Survived      891.0    0.383838    0.486592  0.00    0.0000    0.0000
#
#                  75%        max
# Age           39.000    80.0000
# Fare          31.275   512.3292
# Parch          0.000     9.0000
# PassengerId  982.000  1309.0000
# Pclass         3.000     3.0000
# SibSp          1.000     8.0000
# Survived       1.000     1.0000

# %% [markdown]
# 3. 4- Graphical distribution of data values

# %%
data.hist(bins=50, figsize=(20,15))
plt.show()

# %% [markdown]
# 4. Data Cleansing
#    1. By checking the data information above we notice the missing values in embarked, age, and cabin columns
#       a. There are 4 missing values for attribute embarked. Since the proportion of missing value is 0.22% less than 10%
#          we can impute it.
#
#       b. There are 354 missing values for attribute age. Since the proportion of missing value is 19.87 % greater than 10%
#          we can impute it to avoid losing data.
#
#       c. There are 1374 missing values for attribute cabin. Since the proportion of missing value is 77.10 % greater than 10%
#          so, we discard without losing data.

# %%
# Make sure we know where the missing values are and get the sum
data.keys()
set1 = [i for i in data.keys()]
print((data[set1].isnull().sum()))
# Out:
# Age             263
# Cabin          1014
# Embarked          2
# Fare              1
# Name              0
# Parch             0
# PassengerId       0
# Pclass            0
# Sex               0
# SibSp             0
# Survived        418
# Ticket            0
# dtype: int64

# %%
data
# Out:
#       Age        Cabin Embarked      Fare  \
# 0    22.0          NaN        S    7.2500
# 1    38.0          C85        C   71.2833
# 2    26.0          NaN        S    7.9250
# 3    35.0         C123        S   53.1000
# 4    35.0          NaN        S    8.0500
# 5     NaN          NaN        Q    8.4583
# 6    54.0          E46        S   51.8625
# 7     2.0          NaN        S   21.0750
# 8    27.0          NaN        S   11.1333
# 9    14.0          NaN        C   30.0708
# 10    4.0           G6        S   16.7000
# 11   58.0         C103        S   26.5500
# 12   20.0          NaN        S    8.0500
# 13   39.0          NaN        S   31.2750
# 14   14.0          NaN        S    7.8542
# 15   55.0          NaN        S   16.0000
# 16    2.0          NaN        Q   29.1250
# 17    NaN          NaN        S   13.0000
# 18   31.0          NaN        S   18.0000
# 19    NaN          NaN        C    7.2250
# 20   35.0          NaN        S   26.0000
# ...

# %%
# Get the data where Embarked is not provided
print(data.shape)
data[(data['Embarked'].isnull())]
# Out:
# (1309, 12)
#       Age Cabin Embarked  Fare                                       Name  \
# 61   38.0   B28      NaN  80.0                        Icard, Miss. Amelie
# 829  62.0   B28      NaN  80.0  Stone, Mrs. George Nelson (Martha Evelyn)
#
#      Parch  PassengerId  Pclass     Sex  SibSp  Survived  Ticket
# 61       0           62       1  female      0       1.0  113572
# 829      0          830       1  female      0       1.0  113572

# %%
# Get the data where Age is not provided

data[(data['Age'].isnull())]
# Out:
#      Age  Cabin Embarked      Fare  \
# 5    NaN    NaN        Q    8.4583
# 17   NaN    NaN        S   13.0000
# 19   NaN    NaN        C    7.2250
# 26   NaN    NaN        C    7.2250
# 28   NaN    NaN        Q    7.8792
# 29   NaN    NaN        S    7.8958
# 31   NaN    B78        C  146.5208
# 32   NaN    NaN        Q    7.7500
# 36   NaN    NaN        C    7.2292
# 42   NaN    NaN        C    7.8958
# 45   NaN    NaN        S    8.0500
# 46   NaN    NaN        Q   15.5000
# 47   NaN    NaN        Q    7.7500
# 48   NaN    NaN        C   21.6792
# 55   NaN    C52        S   35.5000
# 64   NaN    NaN        C   27.7208
# 65   NaN    NaN        C   15.2458
# 76   NaN    NaN        S    7.8958
# 77   NaN    NaN        S    8.0500
# 82   NaN    NaN        Q    7.7875
# 87   NaN    NaN        S    8.0500
# 95   NaN    NaN        S    8.0500
# 101  NaN    NaN        S    7.8958
# 107  NaN    NaN        S    7.7750
# 109  NaN    NaN        Q   24.1500
# ...

# %%
# Get the data where Cabin is not provided
data[(data['Cabin'].isnull())]
# Out:
#       Age Cabin Embarked     Fare  \
# 0    22.0   NaN        S   7.2500
# 2    26.0   NaN        S   7.9250
# 4    35.0   NaN        S   8.0500
# 5     NaN   NaN        Q   8.4583
# 7     2.0   NaN        S  21.0750
# 8    27.0   NaN        S  11.1333
# 9    14.0   NaN        C  30.0708
# 12   20.0   NaN        S   8.0500
# 13   39.0   NaN        S  31.2750
# 14   14.0   NaN        S   7.8542
# 15   55.0   NaN        S  16.0000
# 16    2.0   NaN        Q  29.1250
# 17    NaN   NaN        S  13.0000
# 18   31.0   NaN        S  18.0000
# 19    NaN   NaN        C   7.2250
# 20   35.0   NaN        S  26.0000
# 22   15.0   NaN        Q   8.0292
# 24    8.0   NaN        S  21.0750
# 25   38.0   NaN        S  31.3875
# 26    NaN   NaN        C   7.2250
# 28    NaN   NaN        Q   7.8792
# 29    NaN   NaN        S   7.8958
# 30   40.0   NaN        C  27.7208
# 32    NaN   NaN        Q   7.7500
# 33   66.0   NaN        S  10.5000
# 34   28.0   NaN        C  82.1708
# ...

# %%
# Get the data where Pclass, Fare and Cabin are the same to impute Embarked missing values
data_Filter = data[(data.Pclass == 1) & (data.Fare >= 70.0) & (data.Fare <= 90.0)]
data_Filter
# Out:
#       Age    Cabin Embarked     Fare  \
# 1    38.0      C85        C  71.2833
# 34   28.0      NaN        C  82.1708
# 52   49.0      D33        C  76.7292
# 61   38.0      B28      NaN  80.0000
# 62   45.0      C83        S  83.4750
# 102  21.0      D26        S  77.2875
# 124  54.0      D26        S  77.2875
# 139  24.0      B86        C  79.2000
# 218  32.0      D15        C  76.2917
# 224  38.0      C93        S  90.0000
# 230  35.0      C83        S  83.4750
# 245  44.0      C78        Q  90.0000
# 256   NaN      NaN        C  79.2000
# 257  30.0      B77        S  86.5000
# 262  52.0      E67        S  79.6500
# 275  63.0       D7        S  77.9583
# 290  26.0      NaN        S  78.8500
# 310  24.0      C54        C  83.1583
# 366  60.0      D37        C  75.2500
# 375   NaN      NaN        C  82.1708
# 412  33.0      C78        Q  90.0000
# 445   4.0      A34        S  81.8583
# 453  49.0      C92        C  89.1042
# 486  35.0      C93        S  90.0000
# ...

# %%
# Show the histogram of the embarked variable
import seaborn as sns
sns.countplot(x='Embarked', data=data, palette='Set2')
plt.show()

# %%
# Fill the variable embarked missing values using its histogram.
# Most people embaked with fare in the range of $70 to $90 at Southhampton.
# we can impute the missing value with Southhampton,'S'
data['Embarked'].fillna('S', inplace=True)

# %%
# # Fill the variable age missing values using median age 
# From its histogram we can see that its is right skew and median is close to mean
data['Age'].fillna(28, inplace=True)

# %%
# Discard the variable cabin since the information it provides can be got from Pclass anf the Fare
data.drop('Cabin', axis=1, inplace=True)

# %%
# # Fill the variable survived missing values with zero's

data['Survived'].fillna(0, inplace=True)

# %%
data
# Out:
#       Age Embarked      Fare  \
# 0    22.0        S    7.2500
# 1    38.0        C   71.2833
# 2    26.0        S    7.9250
# 3    35.0        S   53.1000
# 4    35.0        S    8.0500
# 5    28.0        Q    8.4583
# 6    54.0        S   51.8625
# 7     2.0        S   21.0750
# 8    27.0        S   11.1333
# 9    14.0        C   30.0708
# 10    4.0        S   16.7000
# 11   58.0        S   26.5500
# 12   20.0        S    8.0500
# 13   39.0        S   31.2750
# 14   14.0        S    7.8542
# 15   55.0        S   16.0000
# 16    2.0        Q   29.1250
# 17   28.0        S   13.0000
# 18   31.0        S   18.0000
# 19   28.0        C    7.2250
# 20   35.0        S   26.0000
# 21   34.0        S   13.0000
# 22   15.0        Q    8.0292
# 23   28.0        S   35.5000
# 24    8.0        S   21.0750
# 25   38.0        S   31.3875
# 26   28.0        C    7.2250
# 27   19.0        S  263.0000
# 28   28.0        Q    7.8792
# 29   28.0        S    7.8958
# ..    ...      ...       ...
# ...

# %% [markdown]
# 4.
#     5. Create a a column to indicate whether a passenger has rare title

# %%
# Create a column for titles by copying the columns of data into data_df
data_df = pd.DataFrame(data=data, columns=['PassengerId', 'Survived', 'Pclass'])

def get_title(name):
    if '.' in name:
        return name.split(',')[1].split('.')[0].strip()
    else:
        return 'Unknow'
data_df['Title'] = data['Name'].map(lambda x: get_title(x))

#data_df['Surname'] = data['Name'].apply(lambda x: x.split(',')[0])
#data_df['Title'] = data['Name'].apply(lambda x: x.split(',')[1].split('.')[0])
#data_df['Name'] = data['Name'].apply(lambda x: x.split(',')[1].split('.')[1])
data_df['Name'] = data['Name'].apply(lambda x: x.split(',')[0]) + data['Name'].apply(lambda x: x.split(',')[1].split('.')[1])
data_df['Sex'] = data['Sex']
data_df['Age'] = data['Age']
data_df['SibSp'] = data['SibSp']
data_df['Parch'] = data['Parch']
data_df['Ticket'] = data['Ticket']
data_df['Fare'] = data['Fare']
data_df['Embarked'] = data['Embarked']
data_df
# Out:
#      PassengerId  Survived  Pclass   Title  \
# 0              1       0.0       3      Mr
# 1              2       1.0       1     Mrs
# 2              3       1.0       3    Miss
# 3              4       1.0       1     Mrs
# 4              5       0.0       3      Mr
# 5              6       0.0       3      Mr
# 6              7       0.0       1      Mr
# 7              8       0.0       3  Master
# 8              9       1.0       3     Mrs
# 9             10       1.0       2     Mrs
# 10            11       1.0       3    Miss
# 11            12       1.0       1    Miss
# 12            13       0.0       3      Mr
# 13            14       0.0       3      Mr
# 14            15       0.0       3    Miss
# 15            16       1.0       2     Mrs
# 16            17       0.0       3  Master
# 17            18       1.0       2      Mr
# 18            19       0.0       3     Mrs
# 19            20       1.0       3     Mrs
# 20            21       0.0       2      Mr
# ...

# %%
data
# Out:
#       Age Embarked      Fare  \
# 0    22.0        S    7.2500
# 1    38.0        C   71.2833
# 2    26.0        S    7.9250
# 3    35.0        S   53.1000
# 4    35.0        S    8.0500
# 5    28.0        Q    8.4583
# 6    54.0        S   51.8625
# 7     2.0        S   21.0750
# 8    27.0        S   11.1333
# 9    14.0        C   30.0708
# 10    4.0        S   16.7000
# 11   58.0        S   26.5500
# 12   20.0        S    8.0500
# 13   39.0        S   31.2750
# 14   14.0        S    7.8542
# 15   55.0        S   16.0000
# 16    2.0        Q   29.1250
# 17   28.0        S   13.0000
# 18   31.0        S   18.0000
# 19   28.0        C    7.2250
# 20   35.0        S   26.0000
# 21   34.0        S   13.0000
# 22   15.0        Q    8.0292
# 23   28.0        S   35.5000
# 24    8.0        S   21.0750
# 25   38.0        S   31.3875
# 26   28.0        C    7.2250
# 27   19.0        S  263.0000
# 28   28.0        Q    7.8792
# 29   28.0        S    7.8958
# ..    ...      ...       ...
# ...

# %%
target = train['Survived'].values
target.shape
# Out:
# (891,)

# %% [markdown]
# # StageII: Model Construction

# %% [markdown]
# 1. Data preparation

# %%
# Fill train dataset with missing value, since variable Age miss 177 value
# variable Cabin miss 687 values and variable Embarked miss 2 values

train['Embarked'].fillna('S', inplace=True)
train['Age'].fillna(28, inplace=True)

train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
# Create new train with different columns
train_df = pd.DataFrame(data=train, columns=['PassengerId', 'Survived', 'Pclass'])
def get_title(name):
    if '.' in name:
        return name.split(',')[1].split('.')[0].strip()
    else:
        return 'Unknow'
train_df['Title'] = train['Name'].map(lambda x: get_title(x))

    
#train_df['Surname'] = train['Name'].apply(lambda x: x.split(',')[0])
#train_df['Name'] = train['Name'].apply(lambda x: x.split(',')[1].split('.')[1])
train_df['Name'] = train['Name'].apply(lambda x: x.split(',')[0]) + train['Name'].apply(lambda x: x.split(',')[1].split('.')[1])
train_df['Sex'] = train['Sex']
train_df['Age'] = train['Age']
train_df['SibSp'] = train['SibSp']
train_df['Parch'] = train['Parch']
train_df['Ticket'] = train['Ticket']
train_df['Fare'] = train['Fare']
train_df['Embarked'] = train['Embarked']
train_df['Age'].fillna(28, inplace=True)
train_df
# Out:
#      PassengerId  Survived  Pclass   Title  \
# 0              1         0       3      Mr
# 1              2         1       1     Mrs
# 2              3         1       3    Miss
# 3              4         1       1     Mrs
# 4              5         0       3      Mr
# 5              6         0       3      Mr
# 6              7         0       1      Mr
# 7              8         0       3  Master
# 8              9         1       3     Mrs
# 9             10         1       2     Mrs
# 10            11         1       3    Miss
# 11            12         1       1    Miss
# 12            13         0       3      Mr
# 13            14         0       3      Mr
# 14            15         0       3    Miss
# 15            16         1       2     Mrs
# 16            17         0       3  Master
# 17            18         1       2      Mr
# 18            19         0       3     Mrs
# 19            20         1       3     Mrs
# 20            21         0       2      Mr
# ...

# %%
# Create histogram of the train dataset
train_df.hist(bins=50, figsize=(20, 15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002568D59C550>,
# ...
#       dtype=object)

# %%
# Convert variable Sex into 0's and 1's using  labelEncoder from sklearn.preprocessing
from sklearn.preprocessing import LabelEncoder
number = LabelEncoder()
train_df['Sex'] = number.fit_transform(train_df['Sex'].astype('str'))
test['Sex'] = number.fit_transform(test['Sex'].astype('str'))

train_df.head(5)
# Out:
#    PassengerId  Survived  Pclass Title  \
# 0            1         0       3    Mr
# 1            2         1       1   Mrs
# 2            3         1       3  Miss
# 3            4         1       1   Mrs
# 4            5         0       3    Mr
#
#                                             Name  Sex   Age  SibSp  Parch  \
# 0                             Braund Owen Harris    1  22.0      1      0
# 1  Cumings John Bradley (Florence Briggs Thayer)    0  38.0      1      0
# 2                                Heikkinen Laina    0  26.0      0      0
# 3         Futrelle Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                            Allen William Henry    1  35.0      0      0
#
#              Ticket     Fare Embarked
# 0         A/5 21171   7.2500        S
# 1          PC 17599  71.2833        C
# 2  STON/O2. 3101282   7.9250        S
# 3            113803  53.1000        S
# 4            373450   8.0500        S

# %% [markdown]
# 2. Convert variable Embarked by adding an indicator (known as a dummy variable) for each category
#      a. Embarked_S for Southhamptons (S)
#      b. Embarked_C for Cherbourg (C)
#      c. Embarked_Q for Queenstown (Q)

# %%
train_df = pd.get_dummies(train_df, columns=['Embarked'])
train_df.head(5)
# Out:
#    PassengerId  Survived  Pclass Title  \
# 0            1         0       3    Mr
# 1            2         1       1   Mrs
# 2            3         1       3  Miss
# 3            4         1       1   Mrs
# 4            5         0       3    Mr
#
#                                             Name  Sex   Age  SibSp  Parch  \
# 0                             Braund Owen Harris    1  22.0      1      0
# 1  Cumings John Bradley (Florence Briggs Thayer)    0  38.0      1      0
# 2                                Heikkinen Laina    0  26.0      0      0
# 3         Futrelle Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                            Allen William Henry    1  35.0      0      0
#
#              Ticket     Fare  Embarked_C  Embarked_Q  Embarked_S
# 0         A/5 21171   7.2500           0           0           1
# 1          PC 17599  71.2833           1           0           0
# 2  STON/O2. 3101282   7.9250           0           0           1
# ...

# %% [markdown]
# 3. Features Scaling so that each can have zero mean and unit variance

# %%
# Import sklearn.preprocessing.StandardScaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# Create a new dataset without the passengerId, name and ticket from train_df to scale
train_WiTitle = train_df.copy()
train2 = train_WiTitle
train2.drop('Title', axis=1, inplace=True)
train2.drop('Name', axis=1, inplace=True)
train2.drop('Ticket', axis=1, inplace=True)
train2 = scaler.fit(train2)
train2
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype uint8, int32, int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
train_WiTitle.keys()
set1 = [i for i in train_WiTitle.keys()]
print((train_WiTitle[set1].isnull().sum()))
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked_C     0
# Embarked_Q     0
# Embarked_S     0
# dtype: int64

# %%
train_WiTitle
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch      Fare  \
# 0              1         0       3    1  22.0      1      0    7.2500
# 1              2         1       1    0  38.0      1      0   71.2833
# 2              3         1       3    0  26.0      0      0    7.9250
# 3              4         1       1    0  35.0      1      0   53.1000
# 4              5         0       3    1  35.0      0      0    8.0500
# 5              6         0       3    1  28.0      0      0    8.4583
# 6              7         0       1    1  54.0      0      0   51.8625
# 7              8         0       3    1   2.0      3      1   21.0750
# 8              9         1       3    0  27.0      0      2   11.1333
# 9             10         1       2    0  14.0      1      0   30.0708
# 10            11         1       3    0   4.0      1      1   16.7000
# 11            12         1       1    0  58.0      0      0   26.5500
# ...

# %%
4. # Splitting train_df dataset into 80% training dataset and 20% validation, test dataset
from sklearn.model_selection import train_test_split
training_set, test_set = train_test_split(train_WiTitle, test_size=0.2)
print(training_set.shape)
print(test_set.shape)
# Out:
# (712, 11)
# (179, 11)

# %% [markdown]
# 5. # Feature Engineering

# %%
# Get data where no title is provided
train_df

#train_filter = train_df[(train_df.Title == 'Unknow')]
# Out:
#      PassengerId  Survived  Pclass   Title  \
# 0              1         0       3      Mr
# 1              2         1       1     Mrs
# 2              3         1       3    Miss
# 3              4         1       1     Mrs
# 4              5         0       3      Mr
# 5              6         0       3      Mr
# 6              7         0       1      Mr
# 7              8         0       3  Master
# 8              9         1       3     Mrs
# 9             10         1       2     Mrs
# 10            11         1       3    Miss
# 11            12         1       1    Miss
# 12            13         0       3      Mr
# 13            14         0       3      Mr
# 14            15         0       3    Miss
# 15            16         1       2     Mrs
# 16            17         0       3  Master
# 17            18         1       2      Mr
# 18            19         0       3     Mrs
# 19            20         1       3     Mrs
# 20            21         0       2      Mr
# ...

# %% [markdown]
# # 2. Building models
#      Use of logistic regression to train the model

# %%
training_set
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch      Fare  \
# 565          566         0       3    1  24.0      2      0   24.1500
# 219          220         0       2    1  30.0      0      0   10.5000
# 719          720         0       3    1  33.0      0      0    7.7750
# 331          332         0       1    1  45.5      0      0   28.5000
# 733          734         0       2    1  23.0      0      0   13.0000
# 793          794         0       1    1  28.0      0      0   30.6958
# 8              9         1       3    0  27.0      0      2   11.1333
# 86            87         0       3    1  16.0      1      3   34.3750
# 488          489         0       3    1  30.0      0      0    8.0500
# 66            67         1       2    0  29.0      0      0   10.5000
# 688          689         0       3    1  18.0      0      0    7.7958
# 6              7         0       1    1  54.0      0      0   51.8625
# ...

# %%
test_set
# Out:
#      PassengerId  Survived  Pclass  Sex    Age  SibSp  Parch     Fare  \
# 573          574         1       3    0  28.00      0      0   7.7500
# 45            46         0       3    1  28.00      0      0   8.0500
# 69            70         0       3    1  26.00      2      0   8.6625
# 739          740         0       3    1  28.00      0      0   7.8958
# 663          664         0       3    1  36.00      0      0   7.4958
# 418          419         0       2    1  30.00      0      0  13.0000
# 459          460         0       3    1  28.00      0      0   7.7500
# 234          235         0       2    1  24.00      0      0  10.5000
# 486          487         1       1    0  35.00      1      0  90.0000
# 471          472         0       3    1  38.00      0      0   8.6625
# 611          612         0       3    1  28.00      0      0   7.0500
# 290          291         1       1    0  26.00      0      0  78.8500
# ...

# %%
# Import logistic regression and apply it to the model
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

cols = ['Pclass', 'Sex', 'Age','SibSp', 'Parch', 'Fare', 'Embarked_C', 'Embarked_Q', 'Embarked_S']
X = training_set[cols]
y = training_set['Survived']
model.fit(X,y)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
# Show parameter values
print(model.intercept_, model.coef_)
test_predictions = model.predict(test_set[cols])
from sklearn.metrics import accuracy_score
print('Test accuracy: ', accuracy_score(test_set['Survived'], test_predictions))
# Out:
# [2.7790242] [[-0.76386935 -2.51567523 -0.03053231 -0.33075455 -0.1901773   0.0073814
#    1.15060804  0.76013416  0.86828199]]
# Test accuracy:  0.8044692737430168

# %%
# 1. Cross validation
from sklearn.model_selection import cross_val_score
print(cross_val_score(model, X, y, cv=3))
# Out:
# [0.79411765 0.80252101 0.80084746]
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
# 2. Confusion matrix
from sklearn.metrics import confusion_matrix
matrix = confusion_matrix(test_set['Survived'], test_predictions)
plt.matshow(matrix)
print(matrix)
# Out:
# [[104  14]
#  [ 21  40]]

# %%
# Precision and recall
from sklearn.metrics import precision_score, recall_score
precision = precision_score(test_set['Survived'], test_predictions)
recall = recall_score(test_set['Survived'], test_predictions)
print(precision, recall)
# Out:
# 0.7407407407407407 0.6557377049180327

# %%
# Precision and recall tradeoff
from sklearn.metrics import f1_score
f1 = f1_score(test_set['Survived'], test_predictions)
f1_formula = 2 / (1 / precision + 1 / recall)
print(f1, f1_formula)
# Out:
# 0.6956521739130433 0.6956521739130435

# %%
# 4. Roc curve and show AUC
from sklearn.metrics import roc_curve
# compute true positive rate and false positive rate
false_positive_rate, true_positive_rate, thresholds = roc_curve(test_set['Survived'], test_predictions)
# plotting them against each other
#def plot_roc_curve(false_positive_rate, true_positive_rate, label=None):
plt.plot(false_positive_rate, true_positive_rate, linewidth=2, label=None)
plt.plot([0, 1], [0, 1], 'r', linewidth=4)
plt.axis([0, 1, 0, 1])
plt.xlabel('False Positive Rate (FPR)', fontsize=16)
plt.ylabel('True Positive Rate (TPR)', fontsize=16)

plt.figure(figsize=(14, 7))
#plot_roc_curve(false_positive_rate, true_positive_rate)
plt.show()
#tpr, npr, thresholds = roc_curve(test_set['Survived'], test_scores)

# %% [markdown]
# # DecisionTreeRegression

# %%
from sklearn.tree import DecisionTreeRegressor
cols = ['Pclass', 'Sex', 'Age','SibSp', 'Parch', 'Fare', 'Embarked_C', 'Embarked_Q', 'Embarked_S']
X1 = training_set[cols]
y1 = training_set['Survived']
tree_reg = DecisionTreeRegressor(random_state=42)
tree_reg.fit(X1, y1)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=42, splitter='best')

# %%
from sklearn.metrics import mean_squared_error
predictions = tree_reg.predict(test_set[cols])
tree_mse = mean_squared_error(test_set['Survived'], predictions)
print('MSE on training set', tree_mse)
# Out:
# MSE on training set 0.25603351955307263

# %%
# Cross_val_score for decisionTree
print(cross_val_score(tree_reg, X1, y1, cv=3))
# Out:
# [ 0.12606306 -0.00349779 -0.06869607]

# %%
from sklearn.metrics import mean_absolute_error

lin_mae = mean_absolute_error(test_set['Survived'], predictions)
print('MAE on training set', lin_mae)
# Out:
# MAE on training set 0.270391061452514

# %%
from sklearn.metrics import roc_curve
# compute true positive rate and false positive rate
false_positive_rate, true_positive_rate, thresholds = roc_curve(test_set['Survived'], test_predictions1)
# plotting them against each other
#def plot_roc_curve(false_positive_rate, true_positive_rate, label=None):
plt.plot(false_positive_rate, true_positive_rate, linewidth=2, label=None)
plt.plot([0, 1], [0, 1], 'r', linewidth=4)
plt.axis([0, 1, 0, 1])
plt.xlabel('False Positive Rate (FPR)', fontsize=16)
plt.ylabel('True Positive Rate (TPR)', fontsize=16)

plt.figure(figsize=(14, 7))
#plot_roc_curve(false_positive_rate, true_positive_rate)
plt.show()

# %% [markdown]
# # RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor

forest_reg = RandomForestRegressor(random_state=42)
forest_reg.fit(training_set[cols], training_set['Survived'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=42, verbose=0, warm_start=False)

# %%
randpredictions = forest_reg.predict(test_set[cols])
forest_mse = mean_squared_error(test_set['Survived'],
                              randpredictions)
print('MSE on training set', forest_mse)
# Out:
# MSE on training set 0.1352457704683363

# %%
# Better evaluation using cross-validation with DecisiontreeRegression
from sklearn.model_selection import cross_val_score

scores = cross_val_score(tree_reg,
                         training_set[cols],
                         training_set['Survived'],
                         scoring="neg_mean_squared_error",
                         cv=10)
print('Decision Tree:', scores)
# Out:
# Decision Tree: [-0.17534722 -0.21583333 -0.2165493  -0.24704225 -0.24383803 -0.32120501
#  -0.18806338 -0.17661972 -0.23943662 -0.16588419]

# %%
# Better evaluation using cross-validation with RandomForestRegression
scores = cross_val_score(forest_reg,
                         training_set[cols],
                         training_set['Survived'],
                         scoring="neg_mean_squared_error",
                         cv=10)
print('Random Forest:', scores)
# Out:
# Random Forest: [-0.15076911 -0.13966152 -0.15041878 -0.13618056 -0.17715108 -0.20160532
#  -0.12720254 -0.13632529 -0.14426732 -0.14065047]

# %%
# Cross_val_score for RandomForestRegression
print(cross_val_score(forest_reg, training_set[cols], training_set['Survived'], cv=3))
# Out:
# [0.35033611 0.32541252 0.35644203]

# %%
# 2. Confusion matrix of randomForest
from sklearn.metrics import confusion_matrix
matrix1 = confusion_matrix(test_set['Survived'], randpredictions)
plt.matshow(matrix1)
print(matrix1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-9f2d6c7b6bb3> in <module>
#       1 # 2. Confusion matrix of randomForest
#       2 from sklearn.metrics import confusion_matrix
# ----> 3 matrix1 = confusion_matrix(test_set['Survived'], randpredictions)
#       4 plt.matshow(matrix1)
#       5 print(matrix1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight)
#     251
#     252     """
# --> 253     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     254     if y_type not in ("binary", "multiclass"):
#     255         raise ValueError("%s is not supported" % y_type)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in _check_targets(y_true, y_pred)
#      79     if len(y_type) > 1:
# ...

# %%
from sklearn.metrics import roc_curve
# compute true positive rate and false positive rate
false_positive_rate, true_positive_rate, thresholds = roc_curve(test_set['Survived'], randpredictions)
# plotting them against each other
#def plot_roc_curve(false_positive_rate, true_positive_rate, label=None):
plt.plot(false_positive_rate, true_positive_rate, linewidth=2, label=None)
plt.plot([0, 1], [0, 1], 'r', linewidth=4)
plt.axis([0, 1, 0, 1])
plt.xlabel('False Positive Rate (FPR)', fontsize=16)
plt.ylabel('True Positive Rate (TPR)', fontsize=16)

plt.figure(figsize=(14, 7))
#plot_roc_curve(false_positive_rate, true_positive_rate)
plt.show()

# %% [markdown]
# # Stage III: Model Selection and Deployment

# %%
# The RandomForestRegression is the best fit. we Will use it to evaluate on 
# the training set and test set, which is validation set

# %%
from sklearn.model_selection import GridSearchCV

param_grid = [
    # try 12 (3×4) combinations of hyperparameters
    {'n_estimators': [3, 10, 30],
     'max_features': [2, 4, 6, 8]},
    # then try 6 (2×3) combinations with bootstrap
    # set as False
    {'bootstrap': [False],
     'n_estimators': [3, 10],
     'max_features': [2, 3, 4]},
  ]

forest_reg = RandomForestRegressor(random_state=42)
# train across 5 folds, that's a total of
# (12+6)*5=90 rounds of training 
grid_search = GridSearchCV(\
                   forest_reg,
                   param_grid,
                   cv=5,
                   scoring='neg_mean_squared_error',
                   return_train_score=True,
                          )
grid_search.fit(training_set[cols],
                training_set['Survived'])
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#            oob_score=False, random_state=42, verbose=0, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid=[{'n_estimators': [3, 10, 30], 'max_features': [2, 4, 6, 8]}, {'bootstrap': [False], 'n_estimators': [3, 10], 'max_features': [2, 3, 4]}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring='neg_mean_squared_error', verbose=0)

# %%
# The best hyperparameter combination found:
print('best parameters:', grid_search.best_params_)

# The best model with above parameters
best_model = grid_search.best_estimator_
train_pred = best_model.predict(training_set[cols])
print('MSE:', mean_squared_error(train_pred,
                                 training_set['Survived']))
scores = cross_val_score(best_model,
                          training_set[cols],
                          training_set['Survived'],
                          cv=10,
                          scoring="neg_mean_squared_error")
print(scores)
# Out:
# best parameters: {'max_features': 4, 'n_estimators': 30}
# MSE: 0.027571339675884106
# [-0.13019813 -0.13114073 -0.15869433 -0.14114618 -0.1712219  -0.20299286
#  -0.1137353  -0.13353982 -0.12899009 -0.13759943]

# %%
# Randomized search
from scipy.stats import randint
from sklearn.model_selection import RandomizedSearchCV

params = {'bootstrap': [True, False],
          'n_estimators': randint(2, 30),
          'max_features': randint(2, 10),}

forest_reg = RandomForestRegressor(random_state=42)

random_search = RandomizedSearchCV(\
                   forest_reg,
                   params,
                   cv=5,
                   scoring='neg_mean_squared_error',
                   return_train_score=True,
                                  )
random_search.fit(training_set[cols],
                  training_set['Survived'])
# Out:
# RandomizedSearchCV(cv=5, error_score='raise-deprecating',
#           estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#            oob_score=False, random_state=42, verbose=0, warm_start=False),
#           fit_params=None, iid='warn', n_iter=10, n_jobs=None,
#           param_distributions={'bootstrap': [True, False], 'n_estimators': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000002568E45A898>, 'max_features': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000002568E45A400>},
#           pre_dispatch='2*n_jobs', random_state=None, refit=True,
#           return_train_score=True, scoring='neg_mean_squared_error',
#           verbose=0)

# %%
# The best hyperparameter combination found:
print('best parameters:', random_search.best_params_)

# The best model with above parameters
best_model = random_search.best_estimator_
train_pred = best_model.predict(training_set[cols])
print('MSE:', mean_squared_error(train_pred,
                                 training_set['Survived']))
scores = cross_val_score(best_model,
                          training_set[cols],
                          training_set['Survived'],
                          cv=10,
                          scoring="neg_mean_squared_error")
print(scores)
# Out:
# best parameters: {'bootstrap': True, 'max_features': 3, 'n_estimators': 8}
# MSE: 0.03217813168640974
# [-0.12805236 -0.16364687 -0.17074096 -0.13766016 -0.18013887 -0.23670451
#  -0.10590895 -0.13451271 -0.13805469 -0.1563683 ]

# %%
# Analyze the best model
feature_importance = best_model.feature_importances_
attributes = training_set.columns
sorted(zip(feature_importance, attributes),
       reverse=True)
# Out:
# [(0.28953548317778643, 'Survived'),
#  (0.2585605463128599, 'Pclass'),
#  (0.23724213098279634, 'SibSp'),
#  (0.09769436155237106, 'PassengerId'),
#  (0.040484007034010755, 'Sex'),
#  (0.03622341009700117, 'Age'),
#  (0.01984670682170441, 'Parch'),
#  (0.014852402858920581, 'Embarked_C'),
#  (0.005560951162549378, 'Fare')]

# %%
# Evaluation the model on test set
test_pred = best_model.predict(test_set[cols])
best_mse = mean_squared_error(test_set['Survived'],
                              test_pred)
print('MSE on test set:', best_mse)
# Out:
# MSE on test set: 0.14128258609012095

# %%
# Evaluation the model on training set
trainSet_pred = best_model.predict(training_set[cols])
best_mse = mean_squared_error(training_set['Survived'],
                              trainSet_pred)
print('MSE on test set:', best_mse)
# Out:
# MSE on test set: 0.03217813168640974
